# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#plt.style.available
#Uncomment above line to see available styles
plt.style.use('seaborn-colorblind')

# %%
wine = pd.read_csv('Data/winemag-data-130k-v2.csv',index_col=0)
pokemon = pd.read_csv('Data/pokemon.csv',index_col=0)

# %%
wine.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#Let's print out top 10 wine producing countries
wine['country'].value_counts().sort_values(ascending=False).head(10).plot.bar()

# %%
#Let's print out top 10 wine producing countries
wine['province'].value_counts().sort_values(ascending=False).head(10).plot.pie(explode=[0,0.1,0.1,0.1])

# %%
#Let's drop null values
print(" Before dropping Null : ",wine.shape)
wine.dropna(inplace=True)
print(" After dropping Null : ",wine.shape)
# Out:
#  Before dropping Null :  (129971, 13)
#  After dropping Null :  (22387, 13)

# %% [markdown]
# We see a drastic drop down in the count of data

# %%
wine.set_index('country',inplace=True)
wine.index.name=None
wine.head(1)
# Out:
#                                           description  \
# US  Much like the regular bottling from 2012, this...
#
#                            designation  points  price province  \
# US  Vintner's Reserve Wild Child Block      87   65.0   Oregon
#
#              region_1           region_2   taster_name taster_twitter_handle  \
# US  Willamette Valley  Willamette Valley  Paul Gregutt           @paulgwine
#
#                                                 title     variety  \
# US  Sweet Cheeks 2012 Vintner's Reserve Wild Child...  Pinot Noir
#
#           winery
# US  Sweet Cheeks

# %%
#Let's plot distrubution of price for US
wine.loc['US','price'].plot.hist()

# %%
#let's see the distribution of points given to wine's
wine.points.plot.hist(alpha=0.35,bins=len(wine.points.unique()))

# %%
#let's see the distribution of price for each wine's
wine.price.plot.hist(alpha=0.35,bins=len(wine.price.unique()))
#len(wine.price.unique())

# %%
wine['points'].value_counts().sort_index().plot.area(alpha=0.25)

# %%
wine['points'].value_counts().sort_index().plot.bar()

# %%
wine[wine['price'] < 100]['price'].plot.hist()

# %%
pokemon.head(3)
# Out:
#                              against_bug  against_dark  against_dragon  \
# abilities
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#                              against_electric  against_fairy  against_fight  \
# abilities
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
#
#                              against_fire  against_flying  against_ghost  \
# abilities
# ['Overgrow', 'Chlorophyll']           2.0             2.0            1.0
# ['Overgrow', 'Chlorophyll']           2.0             2.0            1.0
# ['Overgrow', 'Chlorophyll']           2.0             2.0            1.0
#
# ...

# %%
pokemon.index.unique()
# Out:
# Index(['['Overgrow', 'Chlorophyll']', '['Blaze', 'Solar Power']',
#        '['Torrent', 'Rain Dish']', '['Shield Dust', 'Run Away']',
#        '['Shed Skin']', '['Compoundeyes', 'Tinted Lens']',
#        '['Swarm', 'Sniper']', '['Keen Eye', 'Tangled Feet', 'Big Pecks']',
#        '['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']',
#        '['Keen Eye', 'Sniper']',
#        ...
#        '['Psychic Surge', 'Telepathy']', '['Grassy Surge', 'Telepathy']',
#        '['Misty Surge', 'Telepathy']', '['Unaware']', '['Sturdy']',
#        '['Full Metal Body']', '['Shadow Shield']', '['Beast Boost']',
#        '['Prism Armor']', '['Soul-Heart']'],
#       dtype='object', name='abilities', length=482)

# %%
pokemon.columns
# Out:
# Index(['against_bug', 'against_dark', 'against_dragon', 'against_electric',
#        'against_fairy', 'against_fight', 'against_fire', 'against_flying',
#        'against_ghost', 'against_grass', 'against_ground', 'against_ice',
#        'against_normal', 'against_poison', 'against_psychic', 'against_rock',
#        'against_steel', 'against_water', 'attack', 'base_egg_steps',
#        'base_happiness', 'base_total', 'capture_rate', 'classfication',
#        'defense', 'experience_growth', 'height_m', 'hp', 'japanese_name',
#        'name', 'percentage_male', 'pokedex_number', 'sp_attack', 'sp_defense',
#        'speed', 'type1', 'type2', 'weight_kg', 'generation', 'is_legendary'],
#       dtype='object')

# %%
#Let's drop null values
print(" Before dropping Null : ",pokemon.shape)
wine.dropna(inplace=True)
print(" After dropping Null : ",pokemon.shape)
# Out:
#  Before dropping Null :  (801, 40)
#  After dropping Null :  (801, 40)

# %%
pokemon['type1'].value_counts().sort_index().plot.bar()

# %%
pokemon['type1'].value_counts().sort_index().plot.bar()

# %%
pokemon['weight_kg'].sort_values().plot.hist()

# %%
pokemon['hp'].value_counts().sort_index().plot()

# %%
pokemon['speed'].value_counts().sort_index().plot()

# %% [markdown]
# ### Advance Data Visualization

# %%
wine.head(3)
# Out:
#                                           description  \
# US  Much like the regular bottling from 2012, this...
# US  Soft, supple plum envelopes an oaky structure ...
# US  This wine from the Geneseo district offers aro...
#
#                            designation  points  price    province  \
# US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# US                      Mountain Cuvée      87   19.0  California
# US                 Signature Selection      87   22.0  California
#
#              region_1           region_2     taster_name  \
# US  Willamette Valley  Willamette Valley    Paul Gregutt
# US        Napa Valley               Napa  Virginie Boone
# US        Paso Robles      Central Coast   Matt Kettmann
#
#    taster_twitter_handle                                              title  \
# US           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# US               @vboone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# ...

# %%
wine.plot.scatter(x='price',y='points')

# %%
wine.plot.scatter(x='price',y='points',s=wine['points'],c=wine['points'],colormap='plasma')

# %%
wine.plot.hexbin(x='price',y='points',gridsize=15)

# %% [markdown]
# ### Working with `Pokemon` data set

# %%
pokemon.head()
# Out:
#                              against_bug  against_dark  against_dragon  \
# abilities
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ['Blaze', 'Solar Power']             0.5           1.0             1.0
# ['Blaze', 'Solar Power']             0.5           1.0             1.0
#
#                              against_electric  against_fairy  against_fight  \
# abilities
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
# ['Overgrow', 'Chlorophyll']               0.5            0.5            0.5
# ['Blaze', 'Solar Power']                  1.0            0.5            1.0
# ['Blaze', 'Solar Power']                  1.0            0.5            1.0
#
# ...

# %%
pokemon.columns
# Out:
# Index(['against_bug', 'against_dark', 'against_dragon', 'against_electric',
#        'against_fairy', 'against_fight', 'against_fire', 'against_flying',
#        'against_ghost', 'against_grass', 'against_ground', 'against_ice',
#        'against_normal', 'against_poison', 'against_psychic', 'against_rock',
#        'against_steel', 'against_water', 'attack', 'base_egg_steps',
#        'base_happiness', 'base_total', 'capture_rate', 'classfication',
#        'defense', 'experience_growth', 'height_m', 'hp', 'japanese_name',
#        'name', 'percentage_male', 'pokedex_number', 'sp_attack', 'sp_defense',
#        'speed', 'type1', 'type2', 'weight_kg', 'generation', 'is_legendary'],
#       dtype='object')

# %%
#Let's maek sure that all the columns have same datatype.
all(isinstance(col,str) for col in pokemon.columns)
# Out:
# True

# %%
pokemon['generation'].value_counts().plot.bar()

# %% [markdown]
# ## let's make `name` column as index of pokemon DataFram

# %%
pokemon.set_index('name',inplace=True)
pokemon.head()
# Out:
#             against_bug  against_dark  against_dragon  against_electric  \
# name
# Bulbasaur           1.0           1.0             1.0               0.5
# Ivysaur             1.0           1.0             1.0               0.5
# Venusaur            1.0           1.0             1.0               0.5
# Charmander          0.5           1.0             1.0               1.0
# Charmeleon          0.5           1.0             1.0               1.0
#
#             against_fairy  against_fight  against_fire  against_flying  \
# name
# Bulbasaur             0.5            0.5           2.0             2.0
# Ivysaur               0.5            0.5           2.0             2.0
# Venusaur              0.5            0.5           2.0             2.0
# Charmander            0.5            1.0           0.5             1.0
# Charmeleon            0.5            1.0           0.5             1.0
#
#             against_ghost  against_grass      ...       percentage_male  \
# ...

# %%
# Lets find data for Bulbasur and Charmeleon and compare them
pok_bal = pokemon.loc[['Bulbasaur','Charmeleon']]
pok_bal.head()
# Out:
#             against_bug  against_dark  against_dragon  against_electric  \
# name
# Bulbasaur           1.0           1.0             1.0               0.5
# Charmeleon          0.5           1.0             1.0               1.0
#
#             against_fairy  against_fight  against_fire  against_flying  \
# name
# Bulbasaur             0.5            0.5           2.0             2.0
# Charmeleon            0.5            1.0           0.5             1.0
#
#             against_ghost  against_grass      ...       percentage_male  \
# name                                          ...
# Bulbasaur             1.0           0.25      ...                  88.1
# Charmeleon            1.0           0.50      ...                  88.1
#
#             pokedex_number  sp_attack  sp_defense  speed  type1   type2  \
# name
# Bulbasaur                1         65          65     45  grass  poison
# Charmeleon               5         80          65     80   fire     NaN
#
# ...

# %%
pokemon.loc[:,['attack','weight_kg']].head(10).plot.bar(stacked=True)

# %%
# %matplotlib notebook
pokemon.loc[:,['attack','weight_kg']].head(10).plot.bar(stacked=True)
pokemon.loc[:,'speed'].plot(figsize=(9,7))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
pokemon.loc[:,['attack','weight_kg']].head(10).plot.area(stacked=True,alpha=0.34)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pokemon.columns
# Out:
# Index(['against_bug', 'against_dark', 'against_dragon', 'against_electric',
#        'against_fairy', 'against_fight', 'against_fire', 'against_flying',
#        'against_ghost', 'against_grass', 'against_ground', 'against_ice',
#        'against_normal', 'against_poison', 'against_psychic', 'against_rock',
#        'against_steel', 'against_water', 'attack', 'base_egg_steps',
#        'base_happiness', 'base_total', 'capture_rate', 'classfication',
#        'defense', 'experience_growth', 'height_m', 'hp', 'japanese_name',
#        'percentage_male', 'pokedex_number', 'sp_attack', 'sp_defense', 'speed',
#        'type1', 'type2', 'weight_kg', 'generation', 'is_legendary'],
#       dtype='object')
