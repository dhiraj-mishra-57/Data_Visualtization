# %%
# Importing necessary packages
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('UN_MigFlow_All_CountryFiles/Canada.xlsx',sheet_name='Canada by Citizenship',skipfooter=2,skiprows=range(20))
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...   2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...   2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...   1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...   3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...      0     0     1
# 4  Southern Europe  901   Developed regions     0  ...      0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
#checking data over all columns & if null present
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
# Type        195 non-null object
# Coverage    195 non-null object
# OdName      195 non-null object
# AREA        195 non-null int64
# AreaName    195 non-null object
# REG         195 non-null int64
# RegName     195 non-null object
# DEV         195 non-null int64
# DevName     195 non-null object
# 1980        195 non-null int64
# 1981        195 non-null int64
# 1982        195 non-null int64
# 1983        195 non-null int64
# 1984        195 non-null int64
# 1985        195 non-null int64
# 1986        195 non-null int64
# 1987        195 non-null int64
# 1988        195 non-null int64
# 1989        195 non-null int64
# 1990        195 non-null int64
# 1991        195 non-null int64
# 1992        195 non-null int64
# 1993        195 non-null int64
# 1994        195 non-null int64
# 1995        195 non-null int64
# 1996        195 non-null int64
# ...

# %%
#checking the distribution of data
df.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
#Removing unwanted columns
del df['Type']
del df['Coverage']
df.head()
# Out:
#            OdName  AREA AreaName   REG          RegName  DEV  \
# 0     Afghanistan   935     Asia  5501    Southern Asia  902
# 1         Albania   908   Europe   925  Southern Europe  901
# 2         Algeria   903   Africa   912  Northern Africa  902
# 3  American Samoa   909  Oceania   957        Polynesia  902
# 4         Andorra   908   Europe   925  Southern Europe  901
#
#               DevName  1980  1981  1982  ...   2004  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39  ...   2978  3436  3009  2652  2111
# 1   Developed regions     1     0     0  ...   1450  1223   856   702   560
# 2  Developing regions    80    67    71  ...   3616  3626  4807  3623  4005
# 3  Developing regions     0     1     0  ...      0     0     1     0     0
# 4   Developed regions     0     0     0  ...      0     0     1     1     0
#
#    2009  2010  2011  2012  2013
# 0  1746  1758  2203  2635  2004
# 1   716   561   539   620   603
# 2  5393  4752  4325  3774  4331
# ...

# %%
#Renaming OdName to Country
df.rename(columns={'OdName':'Country'},inplace=True)
#Making Country column as index as it will be easy to filter records
df.set_index(keys='Country',inplace=True)
df.index.name = None
df.head()
# Out:
#                 AREA AreaName   REG          RegName  DEV             DevName  \
# Afghanistan      935     Asia  5501    Southern Asia  902  Developing regions
# Albania          908   Europe   925  Southern Europe  901   Developed regions
# Algeria          903   Africa   912  Northern Africa  902  Developing regions
# American Samoa   909  Oceania   957        Polynesia  902  Developing regions
# Andorra          908   Europe   925  Southern Europe  901   Developed regions
#
#                 1980  1981  1982  1983  ...   2004  2005  2006  2007  2008  \
# Afghanistan       16    39    39    47  ...   2978  3436  3009  2652  2111
# Albania            1     0     0     0  ...   1450  1223   856   702   560
# Algeria           80    67    71    69  ...   3616  3626  4807  3623  4005
# American Samoa     0     1     0     0  ...      0     0     1     0     0
# Andorra            0     0     0     0  ...      0     0     1     1     0
#
#                 2009  2010  2011  2012  2013
# ...

# %%
all(isinstance(columns,str) for columns in df.columns)
# Out:
# False

# %%
#Let's make all the columns to str
#It's good practice to have same data type for plotting
df.columns = map(str,df.columns)

all(isinstance(columns,str) for columns in df.columns)
# Out:
# True

# %%
#let's define year and use it in plotting
years = list(range(2000,2011))
years = list(map(str,years))
years
# Out:
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010']

# %%
#let's plot line graph for China & india

df_CI = df.loc[['China','India'],years]
df_CI.head()
# Out:
#         2000   2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# China  35529  36434  31961  36439  36619  42584  33518  27642  30037  29622
# India  28572  31223  31889  27155  28235  36210  33848  28742  28261  29456
#
#         2010
# China  30391
# India  34235

# %% [markdown]
# # Visualizing Data using Matplotlib<a id="8"></a>

# %% [markdown]
# ## Matplotlib: Standard Python Visualization Library<a id="10"></a>
#
# The primary plotting library we will explore is [Matplotlib](http://matplotlib.org/).  As mentioned on their website:
# >Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# If you are aspiring to create impactful visualization with python, Matplotlib is an essential tool to have at your disposal.

# %% [markdown]
# ### Matplotlib.Pyplot
#
# One of the core aspects of Matplotlib is `matplotlib.pyplot`. It is Matplotlib's scripting layer which we studied in details in the videos about Matplotlib. Recall that it is a collection of command style functions that make Matplotlib work like MATLAB. Each `pyplot` function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc. In this lab, we will work with the scripting layer to learn how to generate line plots. In future labs, we will get to work with the Artist layer as well to experiment first hand how it differs from the scripting layer.

# %% [markdown]
# # Line Pots (Series/Dataframe) <a id="12"></a>

# %% [markdown]
# **What is a line plot and why use it?**
#
# A line chart or line plot is a type of plot which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields.
# Use line plot when you have a continuous data set. These are best suited for trend-based visualizations of data over a period of time.

# %%
df_CI.plot()

# %%
# Now we have an issue while plotting df_CI as we are plotting years over Country
# So to awoid this type of issue we need to take transpose of it

df_T = df_CI.transpose()
df_T.plot()

# %%
#Now we will add few features to improve the graph
# Let's add title,x-label and y-label to it.
# %matplotlib notebook
plt.figure()
plt.xlabel('Years')
plt.ylabel('Immigration over the years')
plt.title('Immigration for China & India over the years')
plt.plot(df_T)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## ``Histogram plots`` ##

# %% [markdown]
# ## What is a histogram? ##
# A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc. An example of a histogram, and the raw data it was constructed from, is shown below:
#
# <img src=https://statistics.laerd.com/statistical-guides/img/histogram-1.png />

# %% [markdown]
# ## Choosing the correct bin width ##
# There is no right or wrong answer as to how wide a bin should be, but there are rules of thumb. You need to make sure that the bins are not too small or too large. Consider the histogram we produced earlier (see above): the following histograms use the same data, but have either much smaller or larger bins, as shown below:
#
# <img src='https://statistics.laerd.com/statistical-guides/img/histogram-4.png'/>

# %%
#Histogram plot : Used to see the distrbution of data
#alpha value is used to add transparency in the graph
df_T.plot(kind='hist',bins=6,alpha=0.45)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#By default the stacked value is 'False'
#The True value is used to see data in different way

df_T.plot(kind='hist',bins=6,alpha=0.45,stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## `Area PLots`##

# %% [markdown]
# An area chart is really similar to a line chart, except that the area between the x axis and the line is filled in with color or shading.
#
# <img src='data:image/jpeg;base64,...' />

# %%
#Getting the sum of the immigrants for each countries

df['Total'] = df.sum(axis=1)
df.sort_values(by='Total',ascending=False,inplace=True)
df_top5 = df.head()

# %%
df_top5 = df_top5.loc[:,years]
df_top5
# Out:
#                                                      2000   2001   2002  \
# India                                               28572  31223  31889
# China                                               35529  36434  31961
# United Kingdom of Great Britain and Northern Ir...   8840  11728   8046
# Philippines                                         10763  13836  11707
# Pakistan                                            15400  16708  15110
#
#                                                      2003   2004   2005  \
# India                                               27155  28235  36210
# China                                               36439  36619  42584
# United Kingdom of Great Britain and Northern Ir...   6797   7533   7258
# Philippines                                         12758  14004  18139
# Pakistan                                            13205  13399  14314
#
#                                                      2006   2007   2008  \
# ...

# %%
df_top5_t = df_top5.transpose()
df_top5_t
# Out:
#       India  China  United Kingdom of Great Britain and Northern Ireland  \
# 2000  28572  35529                                               8840
# 2001  31223  36434                                              11728
# 2002  31889  31961                                               8046
# 2003  27155  36439                                               6797
# 2004  28235  36619                                               7533
# 2005  36210  42584                                               7258
# 2006  33848  33518                                               7140
# 2007  28742  27642                                               8216
# 2008  28261  30037                                               8979
# 2009  29456  29622                                               8876
# 2010  34235  30391                                               8724
#
#       Philippines  Pakistan
# 2000        10763     15400
# 2001        13836     16708
# 2002        11707     15110
# ...

# %%
df_top5_t.index
# Out:
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010'],
#       dtype='object')

# %%
# For any help in notebook you can use "anycomand?" and run the code Eg: "plt.legend?"
# let's change the index values of df_top5 to type integer for plotting
df_top5_t.index = df_top5_t.index.map(int)
# %matplotlib inline
df_top5_t.plot(kind='area',alpha=0.1,stacked=False,figsize=(15,10))
plt.xlabel('Years')
plt.ylabel('Immigration over the years')
plt.title('Immigration for top 5 Countries over the years')
plt.legend(loc=2)

# %% [markdown]
# # Histograms
#
# A histogram is a way of representing the *frequency* distribution of numeric dataset. The way it works is it partitions the x-axis into *bins*, assigns each data point in our dataset to a bin, and then counts the number of data points that have been assigned to each bin. So the y-axis is the frequency or the number of data points in each bin. Note that we can change the bin size and usually one needs to tweak it so that the distribution is displayed nicely.

# %%
df.head()
count,edges = np.histogram(df['2013'])
print(count,':',edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2] : [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df['2013'].plot(kind='hist',figsize=(7,4))

# %%
# %matplotlib inline
df['2013'].plot(kind='hist',stacked=False,figsize=(7,7),xticks=edges,color='darkslateblue')
plt.xlabel('Years')
plt.ylabel('Immigration over the years')
plt.title('Immigration for top 5 Countries over the years')
plt.legend(loc=2)

# %% [markdown]
# # Bar Charts (Dataframe)
#
# A bar plot is a way of representing data where the *length* of the bars represents the magnitude/size of the feature/variable. Bar graphs usually represent numerical and categorical variables grouped in intervals.
#
# To create a bar plot, we can pass one of two arguments via `kind` parameter in `plot()`:
#
# * `kind=bar` creates a *vertical* bar plot
# * `kind=barh` creates a *horizontal* bar plot

# %% [markdown]
# **Vertical bar plot**
#
# In vertical bar graphs, the x-axis is used for labelling, and the length of bars on the y-axis corresponds to the magnitude of the variable being measured. Vertical bar graphs are particuarly useful in analyzing time series data. One disadvantage is that they lack space for text labelling at the foot of each bar.

# %%
year = list(range(1980,2014))
year = list(map(str,year))
df_india = df.loc['India',year]

# %%
plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot
df_india.plot(kind='bar',figsize=(15,10),color='green',alpha=0.45)
plt.show()

# %%
plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot
df_india.plot(kind='barh',figsize=(15,10),color='red',alpha=0.45)
plt.show()

# %%
plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot
df_india.plot(kind='bar',figsize=(15,10),color=['r', 'g', 'b', 'violet','indigo','yellow'],alpha=0.45)
plt.show()

# %% [markdown]
# # Pie Charts <a id="6"></a>
#
# A `pie chart` is a circualr graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
#
# Let's use a pie chart to explore the proportion (percentage) of new immigrants grouped by continents for the entire time period from 1980 to 2013.

# %% [markdown]
# Step 1: Gather data.
#
# We will use *pandas* `groupby` method to summarize the immigration data by `Continent`. The general process of `groupby` involves the following steps:
#
# 1. **Split:** Splitting the data into groups based on some criteria.
# 2. **Apply:** Applying a function to each group independently:
#        .sum()
#        .count()
#        .mean()
#        .std()
#        .aggregate()
#        .apply()
#        .etc..
# 3. **Combine:** Combining the results into a data structure.

# %%
# group countries by continents and apply sum() function 
df_continents = df.groupby('AreaName', axis=0).sum()

# note: the output of the groupby method is a `groupby' object. 
# we can not use it further until we apply a function (eg .sum())
print(type(df.groupby('AreaName', axis=0)))

df_continents.head()
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>
#                                   AREA     REG    DEV   1980   1981   1982  \
# AreaName
# Africa                           48762   49242  48708   3951   4363   3819
# Asia                             45815  109147  44197  31025  34314  30214
# Europe                           39044   39754  38743  39760  44802  42720
# Latin America and the Caribbean  29832   30395  29766  13081  15215  16769
# Northern America                  1810    1810   1802   9378  10030   9074
#
#                                   1983   1984   1985   1986    ...       2005  \
# AreaName                                                       ...
# Africa                            2671   2639   2650   3782    ...      27523
# Asia                             24696  27274  23850  28739    ...     159253
# Europe                           24638  22287  20844  24370    ...      35955
# ...

# %% [markdown]
# Plot the data. We will pass in `kind = 'pie'` keyword, along with the following additional parameters:
# - `autopct` -  is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be `fmt%pct`.
# - `startangle` - rotates the start of the pie chart by angle degrees counterclockwise from the x-axis.
# - `shadow` - Draws a shadow beneath the pie (to give a 3D feel).

# %%
# autopct create %, start angle represent starting point
df_continents['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# The above visual is not very clear, the numbers and text overlap in some instances. Let's make a few modifications to improve the visuals:
#
# * Remove the text labels on the pie chart by passing in `legend` and add it as a seperate legend using `plt.legend()`.
# * Push out the percentages to sit just outside the pie chart by passing in `pctdistance` parameter.
# * Pass in a custom set of colors for continents by passing in `colors` parameter.
# * **Explode** the pie chart to emphasize the lowest three continents (Africa, North America, and Latin America and Carribbean) by pasing in `explode` parameter.

# %%
# autopct create %, start angle represent starting point
mpl.style.use('ggplot') # optional: for ggplot-like style
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0.03, 0, 0.08, 0.1, 0.1] # ratio for each continent with which to offset each wedge.
df_continents['Total'].plot(kind='pie',
                            figsize=(15, 10),
                            pctdistance=1.04,
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow  
                            labels=None,
                            explode = explode_list
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.
plt.legend(labels=df_continents.index,loc=2)
plt.show()

# %% [markdown]
# # Box Plots <a id="8"></a>
#
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# - **Minimun:** Smallest number in the dataset.
# - **First quartile:** Middle number between the `minimum` and the `median`.
# - **Second quartile (Median):** Middle number of the (sorted) dataset.
# - **Third quartile:** Middle number between `median` and `maximum`.
# - **Maximum:** Highest number in the dataset.

# %% [markdown]
# <img src="https://www.oreilly.com/library/view/machine-learning-with/9781785882104/assets/adc57493-16e2-4553-b753-55f781d4d480.png" width=440, align="center">

# %% [markdown]
# To make a `box plot`, we can use `kind=box` in `plot` method invoked on a *pandas* series or dataframe.
#
# Let's plot the box plot for the Japanese immigrants between 1980 - 2013.

# %%
# to get a dataframe, place extra square brackets around 'Japan'.
df_japan = df.loc[['Japan'], year].transpose()
df_japan.head()
# Out:
#       Japan
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246

# %%
df_japan.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of Japanese Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# We can immediately make a few key observations from the plot above:
# 1. The minimum number of immigrants is around 200 (min), maximum number is around 1300 (max), and  median number of immigrants is around 900 (median).
# 2. 25% of the years for period 1980 - 2013 had an annual immigrant count of ~500 or fewer (First quartile).
# 2. 75% of the years for period 1980 - 2013 had an annual immigrant count of ~1100 or fewer (Third quartile).
#
# We can view the actual numbers by calling the `describe()` method on the dataframe.

# %% [markdown]
# # Scatter Plots <a id="10"></a>
#
# A `scatter plot` (2D) is a useful method of comparing variables against each other. `Scatter` plots look similar to `line plots` in that they both map independent and dependent variables on a 2D graph. While the datapoints are connected together by a line in a line plot, they are not connected in a scatter plot. The data in a scatter plot is considered to express a trend. With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.
#
# Let's start by exploring the following:
#
# Using a `scatter plot`, let's visualize the trend of total immigrantion to Canada (all countries combined) for the years 1980 - 2013.

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df[year].sum(axis=0))

# change the years to type int (useful for regression later on)
df_tot.index = map(int, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace = True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()
